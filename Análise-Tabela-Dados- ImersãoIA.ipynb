# %%
#Importar pandas
import pandas as pd

# %% [markdown]
# ### Para fazer uma Análise precisamos entender os dados de um DataFrame
# ## 1°– Ler o arquivo

# %% [markdown]
# produtos_df = pd.read_csv(r'C:\Users\Meu Computador\Downloads\Imersão Alura\Neita_Mattos_Dados_Imersão IA - dados.csv')
# produtos_df

# %% [markdown]
# ## 2° - Informações sobre o DataFrame

# %%
produtos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      1465 non-null   object
#  1   product_name    1465 non-null   object
#  2   category        1465 non-null   object
#  3   actual_price    1465 non-null   object
#  4   product_price   1465 non-null   object
#  5   Percent         1465 non-null   object
#  6   actual price $  1465 non-null   object
#  7   rating          1465 non-null   object
#  8   rating_count    1465 non-null   int64
#  9   about_product   1465 non-null   object
#  10  product_link    1465 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 126.0+ KB

# %% [markdown]
# ## 3° - Mostrar primeiras linhas,  informar quantas linhas dentro dos parênteses.

# %%
produtos_df.head(10)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5  B08Y1TFSP6  pTron Solero TB301 3A Type-C Data and Fast Cha...
# 6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 7  B08DDRGWTJ             MI Usb Type-C Cable Smartphone (Black)
# 8  B008IFXQFU  TP-Link USB WiFi Adapter for PC(TL-WN725N), N1...
# 9  B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#                                             category actual_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...      ₹399,00
# 1  Computers&Accessories|Accessories&Peripherals|...      ₹199,00
# ...

# %% [markdown]
# ## 4° - Mostrar últimas linhas,  informar quantas linhas dentro dos parênteses.

# %%
produtos_df.tail(10)
# Out:
#       product_id                                       product_name  \
# 1455  B00GHL8VP2  USHA 1212 PTC with Adjustable Thermostat Fan H...
# 1456  B0B9JZW1SQ  4 in 1 Handheld Electric Vegetable Cutter Set,...
# 1457  B00TI8E7BI  Philips HD9306/06 1.5-Litre Electric Kettle (M...
# 1458  B07J9KXQCC  Libra Room Heater for Home, Room Heaters Home ...
# 1459  B0B3JSWG81  NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category actual_price  \
# 1455  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...    ₹3.487,77
# 1456  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...      ₹498,00
# ...

# %% [markdown]
# ## 5° - Mostrar se há linhas duplicadas e soma.

# %%
produtos_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 6° - Quantidade de registros únicos por coluna, especificar a coluna.

# %%
produtos_df['product_name'].unique()
# Out:
# array(['Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)',
#        'Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)',
#        'Sounce Fast Phone Charging Cable & Data Sync USB Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini & iOS Devices',
#        ...,
#        'Bajaj Majesty RX10 2000 Watts Heat Convector Room Heater (White, ISI Approved)',
#        'Havells Ventil Air DSP 230mm Exhaust Fan (Pista Green)',
#        'Borosil Jumbo 1000-Watt Grill Sandwich Maker (Black)'],
#       dtype=object)

# %% [markdown]
# ## 7° - Quantidade de registros de cada produto(coluna).

# %%
produtos_df['product_name'].value_counts()
# Out:
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                           5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                    4
# Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)                  3
# MI Braided USB Type-C Cable for Charging Adapter (Red)                                                                                                                              3
# Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)                                                     3
# ...

# %% [markdown]
# ## 8° - Identificar registros Nulos por coluna(NAN)

# %%
produtos_df.isnull().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# actual_price      0
# product_price     0
# Percent           0
# actual price $    0
# rating            0
# rating_count      0
# about_product     0
# product_link      0
# dtype: int64

# %% [markdown]
# ## 9° -  Preencher os dados Nulos quando houver.

# %%
produtos_df.fillna(0,inplace = True)

# %% [markdown]
# ## 10° - Filtrar dados.

# %%
produtos_df.select_dtypes(include=['int64'])
# Out:
#       rating_count
# 0            24269
# 1            43994
# 2             7928
# 3            94363
# 4            16905
# ...            ...
# 1460           109
# 1461          4118
# 1462           468
# 1463          8031
# 1464          6987
#
# [1465 rows x 1 columns]

# %% [markdown]
# ## 11°  Calculando estatísticas descritivas

# %%
produtos_df.describe()
# Out:
#        rating_count
# count  1.465000e+03
# mean   2.166947e+04
# std    9.132905e+04
# min    0.000000e+00
# 25%    9.100000e+02
# 50%    4.003000e+03
# 75%    1.466700e+04
# max    2.051952e+06

# %% [markdown]
# ## 12° -Localizar ( Linha, coluna ou intervalo) com base nos índices

# %%
produtos_df.iloc[5:10, 2:6]
# Out:
#                                             category actual_price  \
# 5  Computers&Accessories|Accessories&Peripherals|...      ₹149,00
# 6  Computers&Accessories|Accessories&Peripherals|...      ₹176,63
# 7  Computers&Accessories|Accessories&Peripherals|...      ₹229,00
# 8  Computers&Accessories|NetworkingDevices|Networ...      ₹499,00
# 9  Computers&Accessories|Accessories&Peripherals|...      ₹199,00
#
#   product_price Percent
# 5       ₹999,00  85,09%
# 6       ₹499,00  64,60%
# 7       ₹299,00  23,41%
# 8       ₹999,00  50,05%
# 9       ₹299,00  33,44%

# %% [markdown]
# ## 13° - Avaliação específica da Linha 6

# %%
produtos_df.loc[6,'rating']
# Out:
# '4,49'

# %% [markdown]
# ## 14° - Exibe o Dataframe em forma de Tabela

# %%
display(produtos_df)
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category actual_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...      ₹399,00
# ...

# %% [markdown]
# ## 15° - Gerar um Boxplot para identificar outliers(dados fora da curva).

# %%
produtos_df.boxplot('rating_count')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 16° - Gráfico de Barras para contar valores únicos em uma coluna.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='rating_count', data = produtos_df)
plt.show()

# %% [markdown]
# ## 17° - Histograma de uma coluna numérica.

# %%
plt.hist(produtos_df['rating_count'], bins=30)
plt.xlabel('rating_count')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### Conclusão:
# ### Estes comandos são a base para começar a entender os dados e definir, conforme o problema, quais procedimentos para a seguinte etapa limpeza.
